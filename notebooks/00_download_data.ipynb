# %%
import sys
sys.path.append("../src/climate_trends/")

from download import download_era5

# %%
years = range(1950, 2025)
variable = "2m_temperature"
# Paris
download_era5(
    variable=variable,
    years=years,
    area= [49.0, 2.0, 48.5, 2.5],
    output_path="../data/raw/era5_paris_t2m.nc"
)
# Out:
# [DOWNLOAD] 2m_temperature -> ../data/raw/era5_paris_t2m.nc
# 2026-04-28 18:32:25,903 INFO Request ID is f6f49ced-7b52-4531-91b8-db8ad16fbb03
# 2026-04-28 18:32:25,958 INFO status has been updated to accepted
# 2026-04-28 18:32:41,746 INFO status has been updated to running
# 2026-04-28 18:34:22,171 INFO status has been updated to successful
# fa4af4636871c5982064979ef3af5012.nc:   0%|          | 0.00/94.3k [00:00<?, ?B/s]
# Saved to ../data/raw/era5_paris_t2m.nc
# PosixPath('../data/raw/era5_paris_t2m.nc')

# %%
# Berlin
download_era5(
    variable=variable,
    years=years,
    area=[52.75, 13.0, 52.25, 13.75],
    output_path="../data/raw/era5_berlin_t2m.nc"
)
# Out:
# [DOWNLOAD] 2m_temperature -> ../data/raw/era5_berlin_t2m.nc
# 2026-04-28 18:41:10,099 INFO Request ID is 1a15862f-b9cc-4290-901c-f82e80ba0896
# 2026-04-28 18:41:10,149 INFO status has been updated to accepted
# 2026-04-28 18:41:25,140 INFO status has been updated to running
# 2026-04-28 18:42:27,583 INFO status has been updated to successful
# 3621d3dc5431b1bc2dfc5c9b264cbdc8.nc:   0%|          | 0.00/98.8k [00:00<?, ?B/s]
# Saved to ../data/raw/era5_berlin_t2m.nc
# PosixPath('../data/raw/era5_berlin_t2m.nc')
